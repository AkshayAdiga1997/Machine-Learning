# %%
import urllib
from bs4 import BeautifulSoup
import requests
import webbrowser
from selenium import webdriver
import pandas as pd
import time
import csv
import re
from nltk.tokenize import word_tokenize,sent_tokenize
from collections import defaultdict
import numpy as np
from random import randint

# %%
df = pd.read_csv("/users/akshayadiga/Downloads/price_list_web_clean_sample.csv")
url=df['URLs']
company=df['Company']
driver=webdriver.Chrome()

# %%
co=0

for x in range(1,len(company)):
    try:
        fi=[]
        if co>150:
            break
#         url[x]="http:/www.fullcontact.com/apps/pricing;http:/www.fullcontact.com/developer/pricing"
        if type(url[x])!=float:
#             print("A")
            co+=1
#             options = webdriver.ChromeOptions()
#             options.add_argument("--start-maximized")

#             driver = webdriver.Chrome(chrome_options=options)
#             driver.set_window_size(1024, 600)
#             driver.maximize_window()
            yo=url[x]
            ww=yo.split(";")
            for b in range(0,len(ww)):
                try:
#                     time.sleep(randint(10,18))
                    po=str(b)
                    qq=ww[b]
                    driver.get(qq)
#                     time.sleep(randint(18,28))
                    elements=driver.find_elements_by_tag_name("div")
                    time.sleep(randint(10,20))
                    d=dict()
                    c=0
        #             print(elements[0].text)
                    for i in elements:
                        f=(i.text).encode('utf-8').strip()
        #                 print(f)
        #                 t=i.get_attribute("class")
                    #     print(t)
                        size = i.size
                        hh=int(math.ceil((size['height']) / 10.0)) * 10
                        wid=int(math.ceil((size['width']) / 10.0)) * 10
                        size['height']=(float(hh))
                        size['width']=(float(wid))
                    #     print(size)
                        size=str(size)
                    #     d.update({f:[size,t]})
                    #     d.update({c:f})
                        d.update({f:size})
                        c+=1

                    v = defaultdict(list)

                    for key, value in sorted(d.iteritems()):
                        v[value].append(key)
                    t=dict()
                    for k,i in v.items():
                    #     if i[0].find("$")!=-1:
                    #         print(k,i)
                        flag=0
                        for j in i:
                            if j.find("$")!=-1 or j.find("Free")!=-1 or j.find("FREE")!=-1 or j.find("Include")!=-1 or j.find("include")!=-1 or j.find("Feature")!=-1 or j.find("feature")!=-1 or j.find("Trial")!=-1 or j.find("TRIAL")!=-1 or j.find("Per")!=-1 or j.find("PER")!=-1 or j.find("Try")!=-1 or j.find("TRY")!=-1:
                                flag=1
                    #         if j.count("$")>1:
                    #             flag=0
                        if flag==1:
        #                     print(len(i))
        #                     print(k,i)
                            t.update({k:i})
                    tnew=t.copy()

        #             print(tnew)
                    if len(t)>0:
                        for k,v in tnew.items():
                            o=k
        #                     print(o)
                            s=o.split("}")
                            s=s[:1]
                            e=s[0].split(",")
        #                     print(e)
                            mul=1
                            for h in e:
                                y=h.split(":")
                                mul*=float(y[1])
                            tnew.update({k:mul})
        #                 print(tnew)
                        r=sorted(tnew, key=tnew.get, reverse=True)
        #                 r=sorted(tnew, key=lambda k: len(tnew[k]), reverse=True)
        #                 print(r)
                        i=(r[0])
        #                 print(t[i])
        #                 print(r)
        #                 i=(t.keys()[0])

                        for k,v in t.items():
                            if len(v)>1:
                                for j in v:
                                    if j.count("\n")>3:
                                        flag=1

                                    else:
                                        flag=0
                                        break
                                if flag==1:
                                    i=k
                                    break
                    
                    
#                     print(t[i],len(t[i]))
                    if len(t[i])<2:
                        elements=driver.find_elements_by_tag_name("section")
                        time.sleep(randint(10,20))
#                         print("Aaaa")
                        d=dict()
                        c=0
            #             print(elements[0].text)
                        for i in elements:
                            f=(i.text).encode('utf-8').strip()
            #                 print(f)
            #                 t=i.get_attribute("class")
                        #     print(t)
                            size = (i.size)
                            hh=int(math.ceil((size['height']) / 10.0)) * 10
                            wid=int(math.ceil((size['width']) / 10.0)) * 10
                            size['height']=(float(hh))
                            size['width']=(float(wid))
                        #     print(size)
                            size=str(size)
                        #     d.update({f:[size,t]})
                        #     d.update({c:f})
                            d.update({f:size})
                            c+=1
#                         print(d)
                        v = defaultdict(list)

                        for key, value in sorted(d.iteritems()):
                            v[value].append(key)
#                         print(v)
#                         print("----asvfsdv---")
                        t=dict()
                        for k,i in v.items():
                        #     if i[0].find("$")!=-1:
                        #         print(k,i)
                            flag=0
                            for j in i:
                                if j.find("$")!=-1 or j.find("Free")!=-1 or j.find("FREE")!=-1 or j.find("Include")!=-1 or j.find("include")!=-1 or j.find("Feature")!=-1 or j.find("feature")!=-1 or j.find("Trial")!=-1 or j.find("TRIAL")!=-1 or j.find("Per")!=-1 or j.find("PER")!=-1 or j.find("Try")!=-1 or j.find("TRY")!=-1:
                                    flag=1
                                else:
                                    flag=0
                                    break
                        #         if j.count("$")>1:
                        #             flag=0
                            if flag==1:
            #                     print(len(i))
            #                     print(k,i)
                                t.update({k:i})
                        tnew=t.copy()

            #             print(tnew)
                        if len(t)>0:
                            for k,v in tnew.items():
                                o=k
            #                     print(o)
                                s=o.split("}")
                                s=s[:1]
                                e=s[0].split(",")
            #                     print(e)
                                mul=1
                                for h in e:
                                    y=h.split(":")
                                    mul*=float(y[1])
                                tnew.update({k:mul})
            #                 print(tnew)
                            r=sorted(tnew, key=tnew.get, reverse=True)
            #                 r=sorted(tnew, key=lambda k: len(tnew[k]), reverse=True)
            #                 print(r)
                            i=(r[0])
            #                 print(t[i])
            #                 print(r)
            #                 i=(t.keys()[0])

                            for k,v in t.items():
                                if len(v)>1:
                                    for j in v:
                                        if j.count("\n")>3:
                                            flag=1

                                        else:
                                            flag=0
                                            break
                                    if flag==1:
                                        i=k
                                        break
        #                 print(t[i])          
                    #     m=len(t.values()[0])
                    #     i=(t.keys()[0])
                    #     for k,v in t.items():
                    #         if len(v)>m:
                    #             m=len(v)
                    #             i=k
    #                     print(t[i],"\n\n")
#                     print(company[x],t[i])
#                     print("\n--------------------------------------\n")
#                     print(t)
                    my_df= pd.DataFrame(t[i])

                    my_df.to_csv('/users/akshayadiga/Downloads/Pricing/'+company[x]+' '+po+'.csv', index=False, header=True)
                except:
                    
#         print("asvsdv")
                    my_df= pd.DataFrame(data=['None'])
                    my_df.to_csv('/users/akshayadiga/Downloads/Pricing/'+company[x]+' '+po+'.csv', index=False, header=True)
#         else:
#             print("A")
#             my_df= pd.DataFrame(data=['None'])
#             my_df.to_csv('/users/akshayadiga/Downloads/Pricing/'+company[x]+'.csv', index=False, header=True)

    except:
#         print("asvsdv")
        my_df= pd.DataFrame(data=['None'])
        my_df.to_csv('/users/akshayadiga/Downloads/Pricing/'+company[x]+'.csv', index=False, header=True)
#         print("Error")
#         t=['A']
#         i=0
#         t[i]=['None']
#         my_df['Pricing']=pd.DataFrame(t[i])
#         my_df.to_csv('/users/akshayadiga/Downloads/Pricing/'+company[x]+'.csv', index=False, header=True)
#         continue
#         print("Error")

# %%
size={'height': 977.6, 'width': 1200.8}
size['height']=math.floor(float(size['height']))
size['width']=math.floor(float(size['width']))

# %%
size
# Out:
# {'height': 977.0, 'width': 1200.0}

# %% [markdown]
# for k,v in d.items():
#     print(k,"----",v)

# %%
t[i]
# Out:
# ['Basic\n$0 /MONTH\nSync with 1 account.\n(Google, iCloud, or Office 365 / Exchange)\nStore 1K contacts.\n10 free business card scans.\n20 contact updates /week\n100 contact lookups /week\n(FullContact for Gmail)\nSign Up',
#  'Team\n$9.99 /MONTH\nPER USER\nBilled annually at $119.99\n\nEverything from Premium, plus:\nTeam contact sharing.\n1,000 business card scans/year.\n500 contact updates /week\n500 contact lookups /week\n(FullContact for Gmail)\nStart 14-Day Free Trial\nNo credit card required.']

# %%
for k,v in t.items():
    if len(v)==3:
        print(k,v)
# Out:
# ("{'width': 360, 'height': 551}", [u'Basic\n$65 per user/month\nBilled annually, or $79 month-to-month.\nIncludes:\nFree job board distribution\nCareer portal\nTask and activity tracking\nClient management [Recruiter]\nBuilt-in standard reports\nResume parsing\nStart free trial', u'Premium\n$99 per user/month\nBilled annually, or $119 month-to-month.\nEverything in Pro, plus:\nExternal search\nMultiple career portals\nCalendar integration\nMultiple workflows\nAPI access\nStart free trial', u'Pro\n$79 per user/month\nBilled annually, or $99 month-to-month.\n Best Value\nEverything in Basic, plus:\nAdvanced job distribution options\nSourcing browser extension\nUser access levels\nIntegrations\nCustomizable workflows and triggers\nInterview scorecards [HR]\nHiring manager access [HR]\nStart free trial'])

# %%
a=5
a+=2
print(a)
# Out:
# 7

# %%
url="http://www.vzaar.com//pricing"
driver=webdriver.Chrome()

# %%
driver.get(url)
time.sleep(randint(10,18))
elements=driver.find_elements_by_tag_name("div")
time.sleep(randint(6,13))
d=dict()
c=0
print(elements[0].text)
for i in elements:
    f=i.text
    print(f)
    t=i.get_attribute("class")
#     print(t)
    size = i.size
#     print(size)
    size=str(size)
#     d.update({f:[size,t]})
#     d.update({c:f})
    d.update({f:size})
    c+=1

v = defaultdict(list)

for key, value in sorted(d.iteritems()):
    v[value].append(key)
t=dict()
for k,i in v.items():
#     if i[0].find("$")!=-1:
#         print(k,i)
    flag=0
    for j in i:
        if j.find("$")!=-1:
            flag=1
#         if j.count("$")>1:
#             flag=0
    if flag==1:
        print(len(i))
        print(k,i)
        t.update({k:i})
if len(t)>0:
    i=(t.keys()[0])
    for k,v in t.items():
        
        for j in v:
            if j.count("\n")>5 and len(v)>1:
                flag=1
            else:
                flag=0
        if flag==1:
            i=k
#     m=len(t.values()[0])
#     i=(t.keys()[0])
#     for k,v in t.items():
#         if len(v)>m:
#             m=len(v)
#             i=k
my_df= pd.DataFrame(t[i])
my_df.to_csv('/users/akshayadiga/Downloads/Pricing/a'+'.csv', index=False, header=True)
# Out:
# FEATURES PRICING USE CASES CONTACT THE PLATFORM
# 1-844-527-2770 Support Resources Blog
# TRY IT FREE
# LOG IN
# FEATURES PRICING USE CASES CONTACT THE PLATFORM
# 1-844-527-2770 Support Resources Blog
# TRY IT FREE
# LOG IN
# FEATURES PRICING USE CASES CONTACT THE PLATFORM
# 1-844-527-2770 Support Resources Blog
# TRY IT FREE
# LOG IN
# FEATURES PRICING USE CASES CONTACT THE PLATFORM
# 1-844-527-2770 Support Resources Blog
# TRY IT FREE
# LOG IN
#
# FEATURES PRICING USE CASES CONTACT THE PLATFORM
# 1-844-527-2770 Support Resources Blog
# TRY IT FREE
# LOG IN
# FEATURES PRICING USE CASES CONTACT THE PLATFORM
# 1-844-527-2770 Support Resources Blog
# TRY IT FREE
# LOG IN
# FLEXIBLE PLANS TO SUIT YOUR NEEDS.
# PAY MONTHLY
# PAY ANNUALLY
# (GET 2 MONTHS FREE)
# SELF SERVICE
# $20.83 /month
# SAVE $50
# START FREE TRIAL
# All core features including...
# Video Analytics
# Customizable video player
# Adaptive streaming
# Domain control
# See all features
# 250 GB Bandwidth
# 250 GB Storage
# Email support
# What happens if I exceed my allowance?
# PREMIUM
# $208.33 /month
# SAVE $500
# START FREE TRIAL
# Self Service, Plus...
# Developer APIs
# Advanced Video Security
# In China Video Playback
# Video Advertising
# See all features
# 1000 GB Bandwidth*
# 1000 GB Storage
# Email & telephone support
# What happens if I exceed my allowance?
# ENTERPRISE
# $416.67 /month
# SAVE $1000
# START FREE TRIAL
# Premium, Plus...
# Live Streaming
# Ultra HD 4K Delivery
# Customer Success Manager
# See all features
# 4 TB Bandwidth*
# 2 TB Storage
# Dedicated account management
# What happens if I exceed my allowance?
# CUSTOM
# Need more bandwidth? Or something a little more specific?
# CONTACT US
# High volume playback
# Flexible bandwidth pack
# Platform developer
# Tell us how you’re using video and we can design a plan that’s right for you. Access Enterprise features, video migrations, developer licenses and more!
# *100GB of allowance can be used towards China playback. Overages apply thereafter. Please contact us if you require additional bandwidth for this territory.
# WHAT HAPPENS IF I EXCEED MY ALLOWANCE?
# Your videos just keep on playing. You simply pay competitive rates for any additional bandwidth you use.
# Bandwidth overage rates are:
# Standard Playback
# $0.50 /GB
# China Playback
# $1.00 /GB
# If you exceed your allowance regularly contact us to discuss your bandwidth needs. We'll find a plan that's right for you. We offer high volume pricing for accounts over 4TB.
# FLEXIBLE BANDWIDTH PACK
# Buy a Flexible Bandwidth Pack if you know your views will rise and fall throughout the year. Use your bandwidth as you wish across the course of the year, without any monthly restrictions. You can even carry over some of your unused bandwidth into a new contract. Contact us to find out more.
# FULL FEATURE LIST
# SELF SERVICE
# PREMIUM
# ENTERPRISE
# FREE TRIAL FREE TRIAL FREE TRIAL
# Pricing
# Billed Annually
# Your card will be charged annually
# $20.83/mo
# Save $50
# $208.33/mo
# Save $500
# $416.67/mo
# Save $1000
# Billed Monthly
# Your card will be charged monthly
# $25/mo
# $250/mo
# $500/mo
# Allowances
# Bandwidth
# 250 GB
# 1000 GB
# 4 TB
# Storage
# 250 GB
# 1000 GB
# 2 TB
# Video limit
# unlimited
# unlimited
# unlimited
# Seats
# 5
# 20
# 20+
# Support
# Email support
# Live chat
# Telephone support
# Customer success manager
# Security
# Domain control
# Advanced embed security
# Encrypted playback
# Password protection
# Video scheduling
# Integration
# Player API
# Developer API
# Migration assistance
# contact
#
# Marketing
# & Advertising
# Video analytics
# Video advertising
# Mail catcher
# White label embed codes
# Player
# Playlists
# Customizable video player
# Multi language subtitles
# Podcasts
# Overages
# Standard playback
# $0.50/GB
# $0.50/GB
# contact
# China playback
# $1.00/GB
# contact
# Upgrades
# Additional domains
# Additional seats
# Additional storage
# Flexible bandwidth pack
# contact
#
# Encoding Quality
# Renditions
# Selectable renditions
# 2
# 3
# 4+
# Do not encode - source
# Ultra low definition
# Low definition
# SD - low
# SD - high
# HD - 720p
# HD - 1080p
# Ultra-HD - 2.5k
# Ultra-HD - 4k
# contact
# PRICING FAQ
# What do I get with my free trial?
# What if I go over my bandwidth?
# Can I purchase more than 5TB?
# What is the price for storage overages?
# Can I have features that aren't included in my plan?
# How much bandwidth do I need?
# Is there a long term contract?
# FLEXIBLE PLANS TO SUIT YOUR NEEDS.
# PAY MONTHLY
# PAY ANNUALLY
# (GET 2 MONTHS FREE)
# SELF SERVICE
# $20.83 /month
# SAVE $50
# START FREE TRIAL
# All core features including...
# Video Analytics
# Customizable video player
# Adaptive streaming
# Domain control
# See all features
# 250 GB Bandwidth
# 250 GB Storage
# Email support
# What happens if I exceed my allowance?
# PREMIUM
# $208.33 /month
# SAVE $500
# START FREE TRIAL
# Self Service, Plus...
# Developer APIs
# Advanced Video Security
# In China Video Playback
# Video Advertising
# See all features
# 1000 GB Bandwidth*
# 1000 GB Storage
# Email & telephone support
# What happens if I exceed my allowance?
# ENTERPRISE
# $416.67 /month
# SAVE $1000
# START FREE TRIAL
# Premium, Plus...
# Live Streaming
# Ultra HD 4K Delivery
# Customer Success Manager
# See all features
# 4 TB Bandwidth*
# 2 TB Storage
# Dedicated account management
# What happens if I exceed my allowance?
# CUSTOM
# Need more bandwidth? Or something a little more specific?
# CONTACT US
# High volume playback
# Flexible bandwidth pack
# Platform developer
# Tell us how you’re using video and we can design a plan that’s right for you. Access Enterprise features, video migrations, developer licenses and more!
# *100GB of allowance can be used towards China playback. Overages apply thereafter. Please contact us if you require additional bandwidth for this territory.
# WHAT HAPPENS IF I EXCEED MY ALLOWANCE?
# Your videos just keep on playing. You simply pay competitive rates for any additional bandwidth you use.
# Bandwidth overage rates are:
# Standard Playback
# $0.50 /GB
# China Playback
# $1.00 /GB
# If you exceed your allowance regularly contact us to discuss your bandwidth needs. We'll find a plan that's right for you. We offer high volume pricing for accounts over 4TB.
# FLEXIBLE BANDWIDTH PACK
# Buy a Flexible Bandwidth Pack if you know your views will rise and fall throughout the year. Use your bandwidth as you wish across the course of the year, without any monthly restrictions. You can even carry over some of your unused bandwidth into a new contract. Contact us to find out more.
# FULL FEATURE LIST
# SELF SERVICE
# PREMIUM
# ENTERPRISE
# FREE TRIAL FREE TRIAL FREE TRIAL
# Pricing
# Billed Annually
# Your card will be charged annually
# $20.83/mo
# Save $50
# $208.33/mo
# Save $500
# $416.67/mo
# Save $1000
# Billed Monthly
# Your card will be charged monthly
# $25/mo
# $250/mo
# $500/mo
# Allowances
# Bandwidth
# 250 GB
# 1000 GB
# 4 TB
# Storage
# 250 GB
# 1000 GB
# 2 TB
# Video limit
# unlimited
# unlimited
# unlimited
# Seats
# 5
# 20
# 20+
# Support
# Email support
# Live chat
# Telephone support
# Customer success manager
# Security
# Domain control
# Advanced embed security
# Encrypted playback
# Password protection
# Video scheduling
# Integration
# Player API
# Developer API
# Migration assistance
# contact
#
# Marketing
# & Advertising
# Video analytics
# Video advertising
# Mail catcher
# White label embed codes
# Player
# Playlists
# Customizable video player
# Multi language subtitles
# Podcasts
# Overages
# Standard playback
# $0.50/GB
# $0.50/GB
# contact
# China playback
# $1.00/GB
# contact
# Upgrades
# Additional domains
# Additional seats
# Additional storage
# Flexible bandwidth pack
# contact
#
# Encoding Quality
# Renditions
# Selectable renditions
# 2
# 3
# 4+
# Do not encode - source
# Ultra low definition
# Low definition
# SD - low
# SD - high
# HD - 720p
# HD - 1080p
# Ultra-HD - 2.5k
# Ultra-HD - 4k
# contact
# PRICING FAQ
# What do I get with my free trial?
# What if I go over my bandwidth?
# Can I purchase more than 5TB?
# What is the price for storage overages?
# Can I have features that aren't included in my plan?
# How much bandwidth do I need?
# Is there a long term contract?
# FLEXIBLE PLANS TO SUIT YOUR NEEDS.
# PAY MONTHLY
# PAY ANNUALLY
# (GET 2 MONTHS FREE)
# SELF SERVICE
# $20.83 /month
# SAVE $50
# START FREE TRIAL
# All core features including...
# Video Analytics
# Customizable video player
# Adaptive streaming
# Domain control
# See all features
# 250 GB Bandwidth
# 250 GB Storage
# Email support
# What happens if I exceed my allowance?
# PREMIUM
# $208.33 /month
# SAVE $500
# START FREE TRIAL
# Self Service, Plus...
# Developer APIs
# Advanced Video Security
# In China Video Playback
# Video Advertising
# See all features
# 1000 GB Bandwidth*
# 1000 GB Storage
# Email & telephone support
# What happens if I exceed my allowance?
# ENTERPRISE
# $416.67 /month
# SAVE $1000
# START FREE TRIAL
# Premium, Plus...
# Live Streaming
# Ultra HD 4K Delivery
# Customer Success Manager
# See all features
# 4 TB Bandwidth*
# 2 TB Storage
# Dedicated account management
# What happens if I exceed my allowance?
# CUSTOM
# Need more bandwidth? Or something a little more specific?
# CONTACT US
# High volume playback
# Flexible bandwidth pack
# Platform developer
# Tell us how you’re using video and we can design a plan that’s right for you. Access Enterprise features, video migrations, developer licenses and more!
# *100GB of allowance can be used towards China playback. Overages apply thereafter. Please contact us if you require additional bandwidth for this territory.
# WHAT HAPPENS IF I EXCEED MY ALLOWANCE?
# Your videos just keep on playing. You simply pay competitive rates for any additional bandwidth you use.
# Bandwidth overage rates are:
# Standard Playback
# $0.50 /GB
# China Playback
# $1.00 /GB
# If you exceed your allowance regularly contact us to discuss your bandwidth needs. We'll find a plan that's right for you. We offer high volume pricing for accounts over 4TB.
# FLEXIBLE BANDWIDTH PACK
# Buy a Flexible Bandwidth Pack if you know your views will rise and fall throughout the year. Use your bandwidth as you wish across the course of the year, without any monthly restrictions. You can even carry over some of your unused bandwidth into a new contract. Contact us to find out more.
# FULL FEATURE LIST
# SELF SERVICE
# PREMIUM
# ENTERPRISE
# FREE TRIAL FREE TRIAL FREE TRIAL
# Pricing
# Billed Annually
# Your card will be charged annually
# $20.83/mo
# Save $50
# $208.33/mo
# Save $500
# $416.67/mo
# Save $1000
# Billed Monthly
# Your card will be charged monthly
# $25/mo
# $250/mo
# $500/mo
# Allowances
# Bandwidth
# 250 GB
# 1000 GB
# 4 TB
# Storage
# 250 GB
# 1000 GB
# 2 TB
# Video limit
# unlimited
# unlimited
# unlimited
# Seats
# 5
# 20
# 20+
# Support
# Email support
# Live chat
# Telephone support
# Customer success manager
# Security
# Domain control
# Advanced embed security
# Encrypted playback
# Password protection
# Video scheduling
# Integration
# Player API
# Developer API
# Migration assistance
# contact
#
# Marketing
# & Advertising
# Video analytics
# Video advertising
# Mail catcher
# White label embed codes
# Player
# Playlists
# Customizable video player
# Multi language subtitles
# Podcasts
# Overages
# Standard playback
# $0.50/GB
# $0.50/GB
# contact
# China playback
# $1.00/GB
# contact
# Upgrades
# Additional domains
# Additional seats
# Additional storage
# Flexible bandwidth pack
# contact
#
# Encoding Quality
# Renditions
# Selectable renditions
# 2
# 3
# 4+
# Do not encode - source
# Ultra low definition
# Low definition
# SD - low
# SD - high
# HD - 720p
# HD - 1080p
# Ultra-HD - 2.5k
# Ultra-HD - 4k
# contact
# PRICING FAQ
# What do I get with my free trial?
# What if I go over my bandwidth?
# Can I purchase more than 5TB?
# What is the price for storage overages?
# Can I have features that aren't included in my plan?
# How much bandwidth do I need?
# Is there a long term contract?
# FLEXIBLE PLANS TO SUIT YOUR NEEDS.
# PAY MONTHLY
# PAY ANNUALLY
# (GET 2 MONTHS FREE)
# SELF SERVICE
# $20.83 /month
# SAVE $50
# START FREE TRIAL
# All core features including...
# Video Analytics
# Customizable video player
# Adaptive streaming
# Domain control
# See all features
# 250 GB Bandwidth
# 250 GB Storage
# Email support
# What happens if I exceed my allowance?
# PREMIUM
# $208.33 /month
# SAVE $500
# START FREE TRIAL
# Self Service, Plus...
# Developer APIs
# Advanced Video Security
# In China Video Playback
# Video Advertising
# See all features
# 1000 GB Bandwidth*
# 1000 GB Storage
# Email & telephone support
# What happens if I exceed my allowance?
# ENTERPRISE
# $416.67 /month
# SAVE $1000
# START FREE TRIAL
# Premium, Plus...
# Live Streaming
# Ultra HD 4K Delivery
# Customer Success Manager
# See all features
# 4 TB Bandwidth*
# 2 TB Storage
# Dedicated account management
# What happens if I exceed my allowance?
# CUSTOM
# Need more bandwidth? Or something a little more specific?
# CONTACT US
# High volume playback
# Flexible bandwidth pack
# Platform developer
# Tell us how you’re using video and we can design a plan that’s right for you. Access Enterprise features, video migrations, developer licenses and more!
# *100GB of allowance can be used towards China playback. Overages apply thereafter. Please contact us if you require additional bandwidth for this territory.
# FLEXIBLE PLANS TO SUIT YOUR NEEDS.
# PAY MONTHLY
# PAY ANNUALLY
# (GET 2 MONTHS FREE)
# SELF SERVICE
# $20.83 /month
# SAVE $50
# START FREE TRIAL
# All core features including...
# Video Analytics
# Customizable video player
# Adaptive streaming
# Domain control
# See all features
# 250 GB Bandwidth
# 250 GB Storage
# Email support
# What happens if I exceed my allowance?
# PREMIUM
# $208.33 /month
# SAVE $500
# START FREE TRIAL
# Self Service, Plus...
# Developer APIs
# Advanced Video Security
# In China Video Playback
# Video Advertising
# See all features
# 1000 GB Bandwidth*
# 1000 GB Storage
# Email & telephone support
# What happens if I exceed my allowance?
# ENTERPRISE
# $416.67 /month
# SAVE $1000
# START FREE TRIAL
# Premium, Plus...
# Live Streaming
# Ultra HD 4K Delivery
# Customer Success Manager
# See all features
# 4 TB Bandwidth*
# 2 TB Storage
# Dedicated account management
# What happens if I exceed my allowance?
# CUSTOM
# Need more bandwidth? Or something a little more specific?
# CONTACT US
# High volume playback
# Flexible bandwidth pack
# Platform developer
# Tell us how you’re using video and we can design a plan that’s right for you. Access Enterprise features, video migrations, developer licenses and more!
# *100GB of allowance can be used towards China playback. Overages apply thereafter. Please contact us if you require additional bandwidth for this territory.
# PAY MONTHLY
# PAY ANNUALLY
# (GET 2 MONTHS FREE)
# SELF SERVICE
# $20.83 /month
# SAVE $50
# START FREE TRIAL
# All core features including...
# Video Analytics
# Customizable video player
# Adaptive streaming
# Domain control
# See all features
# 250 GB Bandwidth
# 250 GB Storage
# Email support
# What happens if I exceed my allowance?
# PREMIUM
# $208.33 /month
# SAVE $500
# START FREE TRIAL
# Self Service, Plus...
# Developer APIs
# Advanced Video Security
# In China Video Playback
# Video Advertising
# See all features
# 1000 GB Bandwidth*
# 1000 GB Storage
# Email & telephone support
# What happens if I exceed my allowance?
# ENTERPRISE
# $416.67 /month
# SAVE $1000
# START FREE TRIAL
# Premium, Plus...
# Live Streaming
# Ultra HD 4K Delivery
# Customer Success Manager
# See all features
# 4 TB Bandwidth*
# 2 TB Storage
# Dedicated account management
# What happens if I exceed my allowance?
# CUSTOM
# Need more bandwidth? Or something a little more specific?
# CONTACT US
# High volume playback
# Flexible bandwidth pack
# Platform developer
# Tell us how you’re using video and we can design a plan that’s right for you. Access Enterprise features, video migrations, developer licenses and more!
# *100GB of allowance can be used towards China playback. Overages apply thereafter. Please contact us if you require additional bandwidth for this territory.
# PAY MONTHLY
# PAY ANNUALLY
# (GET 2 MONTHS FREE)
# PAY MONTHLY
# PAY ANNUALLY
# (GET 2 MONTHS FREE)
# SELF SERVICE
# $20.83 /month
# SAVE $50
# START FREE TRIAL
# All core features including...
# Video Analytics
# Customizable video player
# Adaptive streaming
# Domain control
# See all features
# 250 GB Bandwidth
# 250 GB Storage
# Email support
# What happens if I exceed my allowance?
# PREMIUM
# $208.33 /month
# SAVE $500
# START FREE TRIAL
# Self Service, Plus...
# Developer APIs
# Advanced Video Security
# In China Video Playback
# Video Advertising
# See all features
# 1000 GB Bandwidth*
# 1000 GB Storage
# Email & telephone support
# What happens if I exceed my allowance?
# ENTERPRISE
# $416.67 /month
# SAVE $1000
# START FREE TRIAL
# Premium, Plus...
# Live Streaming
# Ultra HD 4K Delivery
# Customer Success Manager
# See all features
# 4 TB Bandwidth*
# 2 TB Storage
# Dedicated account management
# What happens if I exceed my allowance?
# CUSTOM
# Need more bandwidth? Or something a little more specific?
# CONTACT US
# High volume playback
# Flexible bandwidth pack
# Platform developer
# Tell us how you’re using video and we can design a plan that’s right for you. Access Enterprise features, video migrations, developer licenses and more!
# SELF SERVICE
# $20.83 /month
# SAVE $50
# START FREE TRIAL
# All core features including...
# Video Analytics
# Customizable video player
# Adaptive streaming
# Domain control
# See all features
# 250 GB Bandwidth
# 250 GB Storage
# Email support
# What happens if I exceed my allowance?
# SELF SERVICE
# $20.83 /month
# SAVE $50
# SELF SERVICE
# $20.83 /month
# SAVE $50
# START FREE TRIAL
# All core features including...
# Video Analytics
# Customizable video player
# Adaptive streaming
# Domain control
# See all features
# 250 GB Bandwidth
# 250 GB Storage
# Email support
# What happens if I exceed my allowance?
# What happens if I exceed my allowance?
# PREMIUM
# $208.33 /month
# SAVE $500
# START FREE TRIAL
# Self Service, Plus...
# Developer APIs
# Advanced Video Security
# In China Video Playback
# Video Advertising
# See all features
# 1000 GB Bandwidth*
# 1000 GB Storage
# Email & telephone support
# What happens if I exceed my allowance?
# PREMIUM
# $208.33 /month
# SAVE $500
# PREMIUM
# $208.33 /month
# SAVE $500
# START FREE TRIAL
# Self Service, Plus...
# Developer APIs
# Advanced Video Security
# In China Video Playback
# Video Advertising
# See all features
# 1000 GB Bandwidth*
# 1000 GB Storage
# Email & telephone support
# What happens if I exceed my allowance?
# What happens if I exceed my allowance?
# ENTERPRISE
# $416.67 /month
# SAVE $1000
# START FREE TRIAL
# Premium, Plus...
# Live Streaming
# Ultra HD 4K Delivery
# Customer Success Manager
# See all features
# 4 TB Bandwidth*
# 2 TB Storage
# Dedicated account management
# What happens if I exceed my allowance?
# ENTERPRISE
# $416.67 /month
# SAVE $1000
# ENTERPRISE
# $416.67 /month
# SAVE $1000
# START FREE TRIAL
# Premium, Plus...
# Live Streaming
# Ultra HD 4K Delivery
# Customer Success Manager
# See all features
# 4 TB Bandwidth*
# 2 TB Storage
# Dedicated account management
# What happens if I exceed my allowance?
# What happens if I exceed my allowance?
# CUSTOM
# Need more bandwidth? Or something a little more specific?
# CONTACT US
# High volume playback
# Flexible bandwidth pack
# Platform developer
# Tell us how you’re using video and we can design a plan that’s right for you. Access Enterprise features, video migrations, developer licenses and more!
# CUSTOM
# Need more bandwidth? Or something a little more specific?
# CUSTOM
# CONTACT US
#
# High volume playback
# Flexible bandwidth pack
# Platform developer
#
# Tell us how you’re using video and we can design a plan that’s right for you. Access Enterprise features, video migrations, developer licenses and more!
# *100GB of allowance can be used towards China playback. Overages apply thereafter. Please contact us if you require additional bandwidth for this territory.
# WHAT HAPPENS IF I EXCEED MY ALLOWANCE?
# Your videos just keep on playing. You simply pay competitive rates for any additional bandwidth you use.
# Bandwidth overage rates are:
# Standard Playback
# $0.50 /GB
# China Playback
# $1.00 /GB
# Standard Playback
# $0.50 /GB
# China Playback
# $1.00 /GB
# If you exceed your allowance regularly contact us to discuss your bandwidth needs. We'll find a plan that's right for you. We offer high volume pricing for accounts over 4TB.
# FLEXIBLE BANDWIDTH PACK
# Buy a Flexible Bandwidth Pack if you know your views will rise and fall throughout the year. Use your bandwidth as you wish across the course of the year, without any monthly restrictions. You can even carry over some of your unused bandwidth into a new contract. Contact us to find out more.
# FULL FEATURE LIST
# SELF SERVICE
# PREMIUM
# ENTERPRISE
# FREE TRIAL FREE TRIAL FREE TRIAL
# Pricing
# Billed Annually
# Your card will be charged annually
# $20.83/mo
# Save $50
# $208.33/mo
# Save $500
# $416.67/mo
# Save $1000
# Billed Monthly
# Your card will be charged monthly
# $25/mo
# $250/mo
# $500/mo
# Allowances
# Bandwidth
# 250 GB
# 1000 GB
# 4 TB
# Storage
# 250 GB
# 1000 GB
# 2 TB
# Video limit
# unlimited
# unlimited
# unlimited
# Seats
# 5
# 20
# 20+
# Support
# Email support
# Live chat
# Telephone support
# Customer success manager
# Security
# Domain control
# Advanced embed security
# Encrypted playback
# Password protection
# Video scheduling
# Integration
# Player API
# Developer API
# Migration assistance
# contact
#
# Marketing
# & Advertising
# Video analytics
# Video advertising
# Mail catcher
# White label embed codes
# Player
# Playlists
# Customizable video player
# Multi language subtitles
# Podcasts
# Overages
# Standard playback
# $0.50/GB
# $0.50/GB
# contact
# China playback
# $1.00/GB
# contact
# Upgrades
# Additional domains
# Additional seats
# Additional storage
# Flexible bandwidth pack
# contact
#
# Encoding Quality
# Renditions
# Selectable renditions
# 2
# 3
# 4+
# Do not encode - source
# Ultra low definition
# Low definition
# SD - low
# SD - high
# HD - 720p
# HD - 1080p
# Ultra-HD - 2.5k
# Ultra-HD - 4k
# contact
# SELF SERVICE
# PREMIUM
# ENTERPRISE
# FREE TRIAL FREE TRIAL FREE TRIAL
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# SELF SERVICE
# PREMIUM
# ENTERPRISE
#
# SELF SERVICE
# PREMIUM
# ENTERPRISE
# SELF SERVICE
# PREMIUM
# ENTERPRISE
# FREE TRIAL FREE TRIAL FREE TRIAL
#
# FREE TRIAL FREE TRIAL FREE TRIAL
# FREE TRIAL
# FREE TRIAL
# FREE TRIAL
#
#
#
#
#
#
# Pricing
# Pricing
#
#
#
#
# Billed Annually
# Your card will be charged annually
# $20.83/mo
# Save $50
# $208.33/mo
# Save $500
# $416.67/mo
# Save $1000
# Billed Annually
# Your card will be charged annually
# $20.83/mo
# Save $50
# $208.33/mo
# Save $500
# $416.67/mo
# Save $1000
# $20.83/mo
# Save $50
# $208.33/mo
# Save $500
# $416.67/mo
# Save $1000
# Billed Monthly
# Your card will be charged monthly
# $25/mo
# $250/mo
# $500/mo
# Billed Monthly
# Your card will be charged monthly
# $25/mo
# $250/mo
# $500/mo
# $25/mo
# $250/mo
# $500/mo
#
#
#
#
#
#
#
#
#
#
#
#
#
# Allowances
# Allowances
#
#
#
#
# Bandwidth
# 250 GB
# 1000 GB
# 4 TB
# Bandwidth
#
# 250 GB
# 1000 GB
# 4 TB
# 250 GB
# 1000 GB
# 4 TB
# Storage
# 250 GB
# 1000 GB
# 2 TB
# Storage
#
# 250 GB
# 1000 GB
# 2 TB
# 250 GB
# 1000 GB
# 2 TB
# Video limit
# unlimited
# unlimited
# unlimited
# Video limit
#
# unlimited
# unlimited
# unlimited
# unlimited
# unlimited
# unlimited
# Seats
# 5
# 20
# 20+
# Seats
#
# 5
# 20
# 20+
# 5
# 20
# 20+
#
#
#
#
#
#
#
#
#
#
#
#
#
# Support
# Support
#
#
#
#
# Email support
# Email support
#
#
#
#
#
# Live chat
# Live chat
#
#
#
#
#
# Telephone support
# Telephone support
#
#
#
#
#
# Customer success manager
# Customer success manager
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Security
# Security
#
#
#
#
# Domain control
# Domain control
#
#
#
#
#
# Advanced embed security
# Advanced embed security
#
#
#
#
#
# Encrypted playback
# Encrypted playback
#
#
#
#
#
# Password protection
# Password protection
#
#
#
#
#
# Video scheduling
# Video scheduling
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Integration
# Integration
#
#
#
#
# Player API
# Player API
#
#
#
#
#
# Developer API
# Developer API
#
#
#
#
#
# Migration assistance
# contact
# Migration assistance
#
# contact
#
#
# contact
#
#
#
#
#
#
#
#
#
#
#
#
#
# Marketing
# & Advertising
# Marketing
# & Advertising
#
#
#
#
# Video analytics
# Video analytics
#
#
#
#
#
# Video advertising
# Video advertising
#
#
#
#
#
# Mail catcher
# Mail catcher
#
#
#
#
#
# White label embed codes
# White label embed codes
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Player
# Player
#
#
#
#
# Playlists
# Playlists
#
#
#
#
#
# Customizable video player
# Customizable video player
#
#
#
#
#
# Multi language subtitles
# Multi language subtitles
#
#
#
#
#
# Podcasts
# Podcasts
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Overages
# Overages
#
#
#
#
# Standard playback
# $0.50/GB
# $0.50/GB
# contact
# Standard playback
#
# $0.50/GB
# $0.50/GB
# contact
# $0.50/GB
# $0.50/GB
# contact
# China playback
# $1.00/GB
# contact
# China playback
#
# $1.00/GB
# contact
#
# $1.00/GB
# contact
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upgrades
# Upgrades
#
#
#
#
# Additional domains
# Additional domains
#
#
#
#
#
# Additional seats
# Additional seats
#
#
#
#
#
# Additional storage
# Additional storage
#
#
#
#
#
# Flexible bandwidth pack
# contact
# Flexible bandwidth pack
#
# contact
#
#
# contact
#
#
#
#
#
#
#
#
#
#
#
#
#
# Encoding Quality
# Renditions
# Encoding Quality
# Renditions
#
#
#
#
# Selectable renditions
# 2
# 3
# 4+
# Selectable renditions
#
# 2
# 3
# 4+
# 2
# 3
# 4+
# Do not encode - source
# Do not encode - source
#
#
#
#
#
# Ultra low definition
# Ultra low definition
#
#
#
#
#
# Low definition
# Low definition
#
#
#
#
#
# SD - low
# SD - low
#
#
#
#
#
# SD - high
# SD - high
#
#
#
#
#
# HD - 720p
# HD - 720p
#
#
#
#
#
# HD - 1080p
# HD - 1080p
#
#
#
#
#
# Ultra-HD - 2.5k
# Ultra-HD - 2.5k
#
#
#
#
#
# Ultra-HD - 4k
# contact
# Ultra-HD - 4k
#
# contact
#
#
# contact
#
#
#
#
#
#
# PRICING FAQ
# What do I get with my free trial?
# What if I go over my bandwidth?
# Can I purchase more than 5TB?
# What is the price for storage overages?
# Can I have features that aren't included in my plan?
# How much bandwidth do I need?
# Is there a long term contract?
# What do I get with my free trial?
# What do I get with my free trial?
#
#
# What if I go over my bandwidth?
# What if I go over my bandwidth?
#
#
# Can I purchase more than 5TB?
# Can I purchase more than 5TB?
#
#
# What is the price for storage overages?
# What is the price for storage overages?
#
#
# Can I have features that aren't included in my plan?
# Can I have features that aren't included in my plan?
#
#
# How much bandwidth do I need?
# How much bandwidth do I need?
#
#
# Is there a long term contract?
# Is there a long term contract?
#
#
# PRODUCT
# Features
# Pricing
# Solutions
# Product Updates
# More
# COMPANY
# About
# Team
# Jobs
# Case Studies
# Integrations
# SUPPORT & TOOLS
# Help & Support
# Developers / API
# Tools
# Glossary
# Resources
# Blog
# Keep up with our updates
# 1-844-527-2770
# Talk to us
# Contact
# Drop us a line
# © 2018 vzaar Limited. Registered in England.
# Company Number: 0617 6218 VAT: GB 919 256 111
# Privacy | Terms and conditions | 黔ICP备15008702号
# PRODUCT
# Features
# Pricing
# Solutions
# Product Updates
# More
# COMPANY
# About
# Team
# Jobs
# Case Studies
# Integrations
# SUPPORT & TOOLS
# Help & Support
# Developers / API
# Tools
# Glossary
# Resources
# Blog
# Keep up with our updates
# 1-844-527-2770
# Talk to us
# Contact
# Drop us a line
# © 2018 vzaar Limited. Registered in England.
# Company Number: 0617 6218 VAT: GB 919 256 111
# Privacy | Terms and conditions | 黔ICP备15008702号
# PRODUCT
# Features
# Pricing
# Solutions
# Product Updates
# More
# COMPANY
# About
# Team
# Jobs
# Case Studies
# Integrations
# SUPPORT & TOOLS
# Help & Support
# Developers / API
# Tools
# Glossary
# Resources
# Blog
# Keep up with our updates
# 1-844-527-2770
# Talk to us
# Contact
# Drop us a line
#
#
#
#
#
# 3
# ("{'width': 228, 'height': 140}", [u'ENTERPRISE\n$416.67 /month\nSAVE $1000', u'PREMIUM\n$208.33 /month\nSAVE $500', u'SELF SERVICE\n$20.83 /month\nSAVE $50'])
# 1
# ("{'width': 1200, 'height': 1091}", [u'FLEXIBLE PLANS TO SUIT YOUR NEEDS.\nPAY MONTHLY\nPAY ANNUALLY\n(GET 2 MONTHS FREE)\nSELF SERVICE\n$20.83 /month\nSAVE $50\nSTART FREE TRIAL\nAll core features including...\nVideo Analytics\nCustomizable video player\nAdaptive streaming\nDomain control\nSee all features\n250 GB Bandwidth\n250 GB Storage\nEmail support\nWhat happens if I exceed my allowance?\nPREMIUM\n$208.33 /month\nSAVE $500\nSTART FREE TRIAL\nSelf Service, Plus...\nDeveloper APIs\nAdvanced Video Security\nIn China Video Playback\nVideo Advertising\nSee all features\n1000 GB Bandwidth*\n1000 GB Storage\nEmail & telephone support\nWhat happens if I exceed my allowance?\nENTERPRISE\n$416.67 /month\nSAVE $1000\nSTART FREE TRIAL\nPremium, Plus...\nLive Streaming\nUltra HD 4K Delivery\nCustomer Success Manager\nSee all features\n4 TB Bandwidth*\n2 TB Storage\nDedicated account management\nWhat happens if I exceed my allowance?\nCUSTOM\nNeed more bandwidth? Or something a little more specific?\nCONTACT US\nHigh volume playback\nFlexible bandwidth pack\nPlatform developer\nTell us how you\u2019re using video and we can design a plan that\u2019s right for you. Access Enterprise features, video migrations, developer licenses and more!\n*100GB of allowance can be used towards China playback. Overages apply thereafter. Please contact us if you require additional bandwidth for this territory.'])
# 15
# ("{'width': 188, 'height': 34}", [u'$0.50/GB', u'1000 GB', u'2', u'2 TB', u'20', u'20+', u'250 GB', u'3', u'4 TB', u'4+', u'5', u'ENTERPRISE', u'PREMIUM', u'SELF SERVICE', u'unlimited'])
# 2
# ("{'width': 846, 'height': 48}", [u'Billed Annually\nYour card will be charged annually\n$20.83/mo\nSave $50\n$208.33/mo\nSave $500\n$416.67/mo\nSave $1000', u'Billed Monthly\nYour card will be charged monthly\n$25/mo\n$250/mo\n$500/mo'])
# 7
# ("{'width': 228, 'height': 40}", [u'$20.83 /month', u'$208.33 /month', u'$416.67 /month', u'All core features including...', u'Premium, Plus...', u'See all features', u'Self Service, Plus...'])
# 2
# ("{'width': 565, 'height': 48}", [u'$20.83/mo\nSave $50\n$208.33/mo\nSave $500\n$416.67/mo\nSave $1000', u'$25/mo\n$250/mo\n$500/mo'])
# 1
# ("{'width': 1200, 'height': 887}", [u'PAY MONTHLY\nPAY ANNUALLY\n(GET 2 MONTHS FREE)\nSELF SERVICE\n$20.83 /month\nSAVE $50\nSTART FREE TRIAL\nAll core features including...\nVideo Analytics\nCustomizable video player\nAdaptive streaming\nDomain control\nSee all features\n250 GB Bandwidth\n250 GB Storage\nEmail support\nWhat happens if I exceed my allowance?\nPREMIUM\n$208.33 /month\nSAVE $500\nSTART FREE TRIAL\nSelf Service, Plus...\nDeveloper APIs\nAdvanced Video Security\nIn China Video Playback\nVideo Advertising\nSee all features\n1000 GB Bandwidth*\n1000 GB Storage\nEmail & telephone support\nWhat happens if I exceed my allowance?\nENTERPRISE\n$416.67 /month\nSAVE $1000\nSTART FREE TRIAL\nPremium, Plus...\nLive Streaming\nUltra HD 4K Delivery\nCustomer Success Manager\nSee all features\n4 TB Bandwidth*\n2 TB Storage\nDedicated account management\nWhat happens if I exceed my allowance?\nCUSTOM\nNeed more bandwidth? Or something a little more specific?\nCONTACT US\nHigh volume playback\nFlexible bandwidth pack\nPlatform developer\nTell us how you\u2019re using video and we can design a plan that\u2019s right for you. Access Enterprise features, video migrations, developer licenses and more!\n*100GB of allowance can be used towards China playback. Overages apply thereafter. Please contact us if you require additional bandwidth for this territory.'])
# 6
# ("{'width': 188, 'height': 48}", [u'$20.83/mo\nSave $50', u'$208.33/mo\nSave $500', u'$25/mo', u'$250/mo', u'$416.67/mo\nSave $1000', u'$500/mo'])
# 2
# ("{'width': 270, 'height': 152}", [u'China Playback\n$1.00 /GB', u'Standard Playback\n$0.50 /GB'])
# 6
# ("{'width': 846, 'height': 34}", [u'Bandwidth\n250 GB\n1000 GB\n4 TB', u'Seats\n5\n20\n20+', u'Selectable renditions\n2\n3\n4+', u'Standard playback\n$0.50/GB\n$0.50/GB\ncontact', u'Storage\n250 GB\n1000 GB\n2 TB', u'Video limit\nunlimited\nunlimited\nunlimited'])
# 1
# ("{'width': 565, 'height': 39}", [u'$1.00/GB\ncontact'])
# 3
# ("{'width': 228, 'height': 24}", [u'SAVE $1000', u'SAVE $50', u'SAVE $500'])
# 2
# ("{'width': 188, 'height': 39}", [u'$1.00/GB', u'contact'])
# 7
# ("{'width': 565, 'height': 34}", [u'$0.50/GB\n$0.50/GB\ncontact', u'2\n3\n4+', u'250 GB\n1000 GB\n2 TB', u'250 GB\n1000 GB\n4 TB', u'5\n20\n20+', u'SELF SERVICE\nPREMIUM\nENTERPRISE', u'unlimited\nunlimited\nunlimited'])
# 1
# ("{'width': 846, 'height': 2463}", [u'SELF SERVICE\nPREMIUM\nENTERPRISE\nFREE TRIAL FREE TRIAL FREE TRIAL\nPricing\nBilled Annually\nYour card will be charged annually\n$20.83/mo\nSave $50\n$208.33/mo\nSave $500\n$416.67/mo\nSave $1000\nBilled Monthly\nYour card will be charged monthly\n$25/mo\n$250/mo\n$500/mo\nAllowances\nBandwidth\n250 GB\n1000 GB\n4 TB\nStorage\n250 GB\n1000 GB\n2 TB\nVideo limit\nunlimited\nunlimited\nunlimited\nSeats\n5\n20\n20+\nSupport\nEmail support\nLive chat\nTelephone support\nCustomer success manager\nSecurity\nDomain control\nAdvanced embed security\nEncrypted playback\nPassword protection\nVideo scheduling\nIntegration\nPlayer API\nDeveloper API\nMigration assistance\ncontact\n\nMarketing\n& Advertising\nVideo analytics\nVideo advertising\nMail catcher\nWhite label embed codes\nPlayer\nPlaylists\nCustomizable video player\nMulti language subtitles\nPodcasts\nOverages\nStandard playback\n$0.50/GB\n$0.50/GB\ncontact\nChina playback\n$1.00/GB\ncontact\nUpgrades\nAdditional domains\nAdditional seats\nAdditional storage\nFlexible bandwidth pack\ncontact\n\nEncoding Quality\nRenditions\nSelectable renditions\n2\n3\n4+\nDo not encode - source\nUltra low definition\nLow definition\nSD - low\nSD - high\nHD - 720p\nHD - 1080p\nUltra-HD - 2.5k\nUltra-HD - 4k\ncontact'])
# 1
# ("{'width': 1200, 'height': 5579}", [u"FLEXIBLE PLANS TO SUIT YOUR NEEDS.\nPAY MONTHLY\nPAY ANNUALLY\n(GET 2 MONTHS FREE)\nSELF SERVICE\n$20.83 /month\nSAVE $50\nSTART FREE TRIAL\nAll core features including...\nVideo Analytics\nCustomizable video player\nAdaptive streaming\nDomain control\nSee all features\n250 GB Bandwidth\n250 GB Storage\nEmail support\nWhat happens if I exceed my allowance?\nPREMIUM\n$208.33 /month\nSAVE $500\nSTART FREE TRIAL\nSelf Service, Plus...\nDeveloper APIs\nAdvanced Video Security\nIn China Video Playback\nVideo Advertising\nSee all features\n1000 GB Bandwidth*\n1000 GB Storage\nEmail & telephone support\nWhat happens if I exceed my allowance?\nENTERPRISE\n$416.67 /month\nSAVE $1000\nSTART FREE TRIAL\nPremium, Plus...\nLive Streaming\nUltra HD 4K Delivery\nCustomer Success Manager\nSee all features\n4 TB Bandwidth*\n2 TB Storage\nDedicated account management\nWhat happens if I exceed my allowance?\nCUSTOM\nNeed more bandwidth? Or something a little more specific?\nCONTACT US\nHigh volume playback\nFlexible bandwidth pack\nPlatform developer\nTell us how you\u2019re using video and we can design a plan that\u2019s right for you. Access Enterprise features, video migrations, developer licenses and more!\n*100GB of allowance can be used towards China playback. Overages apply thereafter. Please contact us if you require additional bandwidth for this territory.\nWHAT HAPPENS IF I EXCEED MY ALLOWANCE?\nYour videos just keep on playing. You simply pay competitive rates for any additional bandwidth you use.\nBandwidth overage rates are:\nStandard Playback\n$0.50 /GB\nChina Playback\n$1.00 /GB\nIf you exceed your allowance regularly contact us to discuss your bandwidth needs. We'll find a plan that's right for you. We offer high volume pricing for accounts over 4TB.\nFLEXIBLE BANDWIDTH PACK\nBuy a Flexible Bandwidth Pack if you know your views will rise and fall throughout the year. Use your bandwidth as you wish across the course of the year, without any monthly restrictions. You can even carry over some of your unused bandwidth into a new contract. Contact us to find out more.\nFULL FEATURE LIST\nSELF SERVICE\nPREMIUM\nENTERPRISE\nFREE TRIAL FREE TRIAL FREE TRIAL\nPricing\nBilled Annually\nYour card will be charged annually\n$20.83/mo\nSave $50\n$208.33/mo\nSave $500\n$416.67/mo\nSave $1000\nBilled Monthly\nYour card will be charged monthly\n$25/mo\n$250/mo\n$500/mo\nAllowances\nBandwidth\n250 GB\n1000 GB\n4 TB\nStorage\n250 GB\n1000 GB\n2 TB\nVideo limit\nunlimited\nunlimited\nunlimited\nSeats\n5\n20\n20+\nSupport\nEmail support\nLive chat\nTelephone support\nCustomer success manager\nSecurity\nDomain control\nAdvanced embed security\nEncrypted playback\nPassword protection\nVideo scheduling\nIntegration\nPlayer API\nDeveloper API\nMigration assistance\ncontact\n\nMarketing\n& Advertising\nVideo analytics\nVideo advertising\nMail catcher\nWhite label embed codes\nPlayer\nPlaylists\nCustomizable video player\nMulti language subtitles\nPodcasts\nOverages\nStandard playback\n$0.50/GB\n$0.50/GB\ncontact\nChina playback\n$1.00/GB\ncontact\nUpgrades\nAdditional domains\nAdditional seats\nAdditional storage\nFlexible bandwidth pack\ncontact\n\nEncoding Quality\nRenditions\nSelectable renditions\n2\n3\n4+\nDo not encode - source\nUltra low definition\nLow definition\nSD - low\nSD - high\nHD - 720p\nHD - 1080p\nUltra-HD - 2.5k\nUltra-HD - 4k\ncontact\nPRICING FAQ\nWhat do I get with my free trial?\nWhat if I go over my bandwidth?\nCan I purchase more than 5TB?\nWhat is the price for storage overages?\nCan I have features that aren't included in my plan?\nHow much bandwidth do I need?\nIs there a long term contract?"])
# 1
# ("{'width': 1200, 'height': 699}", [u'SELF SERVICE\n$20.83 /month\nSAVE $50\nSTART FREE TRIAL\nAll core features including...\nVideo Analytics\nCustomizable video player\nAdaptive streaming\nDomain control\nSee all features\n250 GB Bandwidth\n250 GB Storage\nEmail support\nWhat happens if I exceed my allowance?\nPREMIUM\n$208.33 /month\nSAVE $500\nSTART FREE TRIAL\nSelf Service, Plus...\nDeveloper APIs\nAdvanced Video Security\nIn China Video Playback\nVideo Advertising\nSee all features\n1000 GB Bandwidth*\n1000 GB Storage\nEmail & telephone support\nWhat happens if I exceed my allowance?\nENTERPRISE\n$416.67 /month\nSAVE $1000\nSTART FREE TRIAL\nPremium, Plus...\nLive Streaming\nUltra HD 4K Delivery\nCustomer Success Manager\nSee all features\n4 TB Bandwidth*\n2 TB Storage\nDedicated account management\nWhat happens if I exceed my allowance?\nCUSTOM\nNeed more bandwidth? Or something a little more specific?\nCONTACT US\nHigh volume playback\nFlexible bandwidth pack\nPlatform developer\nTell us how you\u2019re using video and we can design a plan that\u2019s right for you. Access Enterprise features, video migrations, developer licenses and more!'])
# 4
# ("{'width': 846, 'height': 39}", [u'China playback\n$1.00/GB\ncontact', u'Flexible bandwidth pack\ncontact', u'Migration assistance\ncontact', u'Ultra-HD - 4k\ncontact'])
# 1
# ("{'width': 1200, 'height': 202}", [u'Standard Playback\n$0.50 /GB\nChina Playback\n$1.00 /GB'])
# 3
# ("{'width': 264, 'height': 669}", [u'ENTERPRISE\n$416.67 /month\nSAVE $1000\nSTART FREE TRIAL\nPremium, Plus...\nLive Streaming\nUltra HD 4K Delivery\nCustomer Success Manager\nSee all features\n4 TB Bandwidth*\n2 TB Storage\nDedicated account management\nWhat happens if I exceed my allowance?', u'PREMIUM\n$208.33 /month\nSAVE $500\nSTART FREE TRIAL\nSelf Service, Plus...\nDeveloper APIs\nAdvanced Video Security\nIn China Video Playback\nVideo Advertising\nSee all features\n1000 GB Bandwidth*\n1000 GB Storage\nEmail & telephone support\nWhat happens if I exceed my allowance?', u'SELF SERVICE\n$20.83 /month\nSAVE $50\nSTART FREE TRIAL\nAll core features including...\nVideo Analytics\nCustomizable video player\nAdaptive streaming\nDomain control\nSee all features\n250 GB Bandwidth\n250 GB Storage\nEmail support\nWhat happens if I exceed my allowance?'])

# %%
for k,v in t.items():
    flag=0
    for j in v:
        if j.count("\n")>5 and len(v)>1:
            flag=1
        else:
            flag=0
    if flag==1:
        print(k,v)
# Out:
# ("{'width': 264, 'height': 669}", [u'ENTERPRISE\n$416.67 /month\nSAVE $1000\nSTART FREE TRIAL\nPremium, Plus...\nLive Streaming\nUltra HD 4K Delivery\nCustomer Success Manager\nSee all features\n4 TB Bandwidth*\n2 TB Storage\nDedicated account management\nWhat happens if I exceed my allowance?', u'PREMIUM\n$208.33 /month\nSAVE $500\nSTART FREE TRIAL\nSelf Service, Plus...\nDeveloper APIs\nAdvanced Video Security\nIn China Video Playback\nVideo Advertising\nSee all features\n1000 GB Bandwidth*\n1000 GB Storage\nEmail & telephone support\nWhat happens if I exceed my allowance?', u'SELF SERVICE\n$20.83 /month\nSAVE $50\nSTART FREE TRIAL\nAll core features including...\nVideo Analytics\nCustomizable video player\nAdaptive streaming\nDomain control\nSee all features\n250 GB Bandwidth\n250 GB Storage\nEmail support\nWhat happens if I exceed my allowance?'])

# %%
d
# Out:
# {u'': "{'width': 0, 'height': 0}",
#  u'$0.50/GB': "{'width': 188, 'height': 34}",
#  u'$0.50/GB\n$0.50/GB\ncontact': "{'width': 565, 'height': 34}",
#  u'$1.00/GB': "{'width': 188, 'height': 39}",
#  u'$1.00/GB\ncontact': "{'width': 565, 'height': 39}",
#  u'$20.83 /month': "{'width': 228, 'height': 40}",
#  u'$20.83/mo\nSave $50': "{'width': 188, 'height': 48}",
#  u'$20.83/mo\nSave $50\n$208.33/mo\nSave $500\n$416.67/mo\nSave $1000': "{'width': 565, 'height': 48}",
#  u'$208.33 /month': "{'width': 228, 'height': 40}",
#  u'$208.33/mo\nSave $500': "{'width': 188, 'height': 48}",
#  u'$25/mo': "{'width': 188, 'height': 48}",
#  u'$25/mo\n$250/mo\n$500/mo': "{'width': 565, 'height': 48}",
#  u'$250/mo': "{'width': 188, 'height': 48}",
#  u'$416.67 /month': "{'width': 228, 'height': 40}",
#  u'$416.67/mo\nSave $1000': "{'width': 188, 'height': 48}",
#  u'$500/mo': "{'width': 188, 'height': 48}",
#  u'*100GB of allowance can be used towards China playback. Overages apply thereafter. Please contact us if you require additional bandwidth for this territory.': "{'width': 1200, 'height': 78}",
#  u'1000 GB': "{'width': 188, 'height': 34}",
#  u'1000 GB Bandwidth*\n1000 GB Storage\nEmail & telephone support\nWhat happens if I exceed my allowance?': "{'width': 228, 'height': 178}",
#  u'2': "{'width': 188, 'height': 34}",
#  u'2\n3\n4+': "{'width': 565, 'height': 34}",
#  u'2 TB': "{'width': 188, 'height': 34}",
#  u'20': "{'width': 188, 'height': 34}",
#  u'20+': "{'width': 188, 'height': 34}",
#  u'250 GB': "{'width': 188, 'height': 34}",
#  u'250 GB\n1000 GB\n2 TB': "{'width': 565, 'height': 34}",
#  u'250 GB\n1000 GB\n4 TB': "{'width': 565, 'height': 34}",
#  u'250 GB Bandwidth\n250 GB Storage\nEmail support\nWhat happens if I exceed my allowance?': "{'width': 228, 'height': 178}",
#  u'3': "{'width': 188, 'height': 34}",
#  u'4 TB': "{'width': 188, 'height': 34}",
#  u'4 TB Bandwidth*\n2 TB Storage\nDedicated account management\nWhat happens if I exceed my allowance?': "{'width': 228, 'height': 178}",
#  u'4+': "{'width': 188, 'height': 34}",
#  u'5': "{'width': 188, 'height': 34}",
#  u'5\n20\n20+': "{'width': 565, 'height': 34}",
#  u'Additional domains': "{'width': 281, 'height': 39}",
#  u'Additional seats': "{'width': 281, 'height': 39}",
#  u'Additional storage': "{'width': 281, 'height': 39}",
#  u'Advanced embed security': "{'width': 281, 'height': 39}",
#  u'All core features including...': "{'width': 228, 'height': 40}",
#  u'Allowances': "{'width': 281, 'height': 34}",
#  u'Bandwidth': "{'width': 281, 'height': 34}",
#  u'Bandwidth\n250 GB\n1000 GB\n4 TB': "{'width': 846, 'height': 34}",
#  u'Bandwidth overage rates are:': "{'width': 1200, 'height': 64}",
#  u'Billed Annually\nYour card will be charged annually': "{'width': 281, 'height': 48}",
#  u'Billed Annually\nYour card will be charged annually\n$20.83/mo\nSave $50\n$208.33/mo\nSave $500\n$416.67/mo\nSave $1000': "{'width': 846, 'height': 48}",
#  u'Billed Monthly\nYour card will be charged monthly': "{'width': 281, 'height': 48}",
#  u'Billed Monthly\nYour card will be charged monthly\n$25/mo\n$250/mo\n$500/mo': "{'width': 846, 'height': 48}",
#  u'Buy a Flexible Bandwidth Pack if you know your views will rise and fall throughout the year. Use your bandwidth as you wish across the course of the year, without any monthly restrictions. You can even carry over some of your unused bandwidth into a new contract. Contact us to find out more.': "{'width': 1200, 'height': 160}",
#  u'CONTACT US': "{'width': 230, 'height': 80}",
#  u'CUSTOM': "{'width': 230, 'height': 56}",
#  u'CUSTOM\nNeed more bandwidth? Or something a little more specific?': "{'width': 230, 'height': 140}",
#  u'CUSTOM\nNeed more bandwidth? Or something a little more specific?\nCONTACT US\nHigh volume playback\nFlexible bandwidth pack\nPlatform developer\nTell us how you\u2019re using video and we can design a plan that\u2019s right for you. Access Enterprise features, video migrations, developer licenses and more!': "{'width': 264, 'height': 667}",
#  u"Can I have features that aren't included in my plan?": "{'width': 904, 'height': 72}",
#  u'Can I purchase more than 5TB?': "{'width': 904, 'height': 72}",
#  u'China Playback\n$1.00 /GB': "{'width': 270, 'height': 152}",
#  u'China playback': "{'width': 281, 'height': 39}",
#  u'China playback\n$1.00/GB\ncontact': "{'width': 846, 'height': 39}",
#  u'Customer success manager': "{'width': 281, 'height': 68}",
#  u'Customizable video player': "{'width': 281, 'height': 39}",
#  u'Developer API': "{'width': 281, 'height': 39}",
#  u'Developer APIs\nAdvanced Video Security\nIn China Video Playback\nVideo Advertising': "{'width': 228, 'height': 124}",
#  u'Do not encode - source': "{'width': 281, 'height': 39}",
#  u'Domain control': "{'width': 281, 'height': 39}",
#  u'ENTERPRISE': "{'width': 188, 'height': 34}",
#  u'ENTERPRISE\n$416.67 /month\nSAVE $1000': "{'width': 228, 'height': 140}",
#  u'ENTERPRISE\n$416.67 /month\nSAVE $1000\nSTART FREE TRIAL\nPremium, Plus...\nLive Streaming\nUltra HD 4K Delivery\nCustomer Success Manager\nSee all features\n4 TB Bandwidth*\n2 TB Storage\nDedicated account management\nWhat happens if I exceed my allowance?': "{'width': 264, 'height': 669}",
#  u'Email support': "{'width': 281, 'height': 39}",
#  u'Encoding Quality\nRenditions': "{'width': 281, 'height': 68}",
#  u'Encrypted playback': "{'width': 281, 'height': 39}",
#  u'FEATURES PRICING USE CASES CONTACT THE PLATFORM\n1-844-527-2770 Support Resources Blog\nTRY IT FREE\nLOG IN': "{'width': 1006, 'height': 63}",
#  u'FLEXIBLE BANDWIDTH PACK': "{'width': 1200, 'height': 48}",
#  u'FLEXIBLE PLANS TO SUIT YOUR NEEDS.\nPAY MONTHLY\nPAY ANNUALLY\n(GET 2 MONTHS FREE)\nSELF SERVICE\n$20.83 /month\nSAVE $50\nSTART FREE TRIAL\nAll core features including...\nVideo Analytics\nCustomizable video player\nAdaptive streaming\nDomain control\nSee all features\n250 GB Bandwidth\n250 GB Storage\nEmail support\nWhat happens if I exceed my allowance?\nPREMIUM\n$208.33 /month\nSAVE $500\nSTART FREE TRIAL\nSelf Service, Plus...\nDeveloper APIs\nAdvanced Video Security\nIn China Video Playback\nVideo Advertising\nSee all features\n1000 GB Bandwidth*\n1000 GB Storage\nEmail & telephone support\nWhat happens if I exceed my allowance?\nENTERPRISE\n$416.67 /month\nSAVE $1000\nSTART FREE TRIAL\nPremium, Plus...\nLive Streaming\nUltra HD 4K Delivery\nCustomer Success Manager\nSee all features\n4 TB Bandwidth*\n2 TB Storage\nDedicated account management\nWhat happens if I exceed my allowance?\nCUSTOM\nNeed more bandwidth? Or something a little more specific?\nCONTACT US\nHigh volume playback\nFlexible bandwidth pack\nPlatform developer\nTell us how you\u2019re using video and we can design a plan that\u2019s right for you. Access Enterprise features, video migrations, developer licenses and more!\n*100GB of allowance can be used towards China playback. Overages apply thereafter. Please contact us if you require additional bandwidth for this territory.': "{'width': 1200, 'height': 1091}",
#  u"FLEXIBLE PLANS TO SUIT YOUR NEEDS.\nPAY MONTHLY\nPAY ANNUALLY\n(GET 2 MONTHS FREE)\nSELF SERVICE\n$20.83 /month\nSAVE $50\nSTART FREE TRIAL\nAll core features including...\nVideo Analytics\nCustomizable video player\nAdaptive streaming\nDomain control\nSee all features\n250 GB Bandwidth\n250 GB Storage\nEmail support\nWhat happens if I exceed my allowance?\nPREMIUM\n$208.33 /month\nSAVE $500\nSTART FREE TRIAL\nSelf Service, Plus...\nDeveloper APIs\nAdvanced Video Security\nIn China Video Playback\nVideo Advertising\nSee all features\n1000 GB Bandwidth*\n1000 GB Storage\nEmail & telephone support\nWhat happens if I exceed my allowance?\nENTERPRISE\n$416.67 /month\nSAVE $1000\nSTART FREE TRIAL\nPremium, Plus...\nLive Streaming\nUltra HD 4K Delivery\nCustomer Success Manager\nSee all features\n4 TB Bandwidth*\n2 TB Storage\nDedicated account management\nWhat happens if I exceed my allowance?\nCUSTOM\nNeed more bandwidth? Or something a little more specific?\nCONTACT US\nHigh volume playback\nFlexible bandwidth pack\nPlatform developer\nTell us how you\u2019re using video and we can design a plan that\u2019s right for you. Access Enterprise features, video migrations, developer licenses and more!\n*100GB of allowance can be used towards China playback. Overages apply thereafter. Please contact us if you require additional bandwidth for this territory.\nWHAT HAPPENS IF I EXCEED MY ALLOWANCE?\nYour videos just keep on playing. You simply pay competitive rates for any additional bandwidth you use.\nBandwidth overage rates are:\nStandard Playback\n$0.50 /GB\nChina Playback\n$1.00 /GB\nIf you exceed your allowance regularly contact us to discuss your bandwidth needs. We'll find a plan that's right for you. We offer high volume pricing for accounts over 4TB.\nFLEXIBLE BANDWIDTH PACK\nBuy a Flexible Bandwidth Pack if you know your views will rise and fall throughout the year. Use your bandwidth as you wish across the course of the year, without any monthly restrictions. You can even carry over some of your unused bandwidth into a new contract. Contact us to find out more.\nFULL FEATURE LIST\nSELF SERVICE\nPREMIUM\nENTERPRISE\nFREE TRIAL FREE TRIAL FREE TRIAL\nPricing\nBilled Annually\nYour card will be charged annually\n$20.83/mo\nSave $50\n$208.33/mo\nSave $500\n$416.67/mo\nSave $1000\nBilled Monthly\nYour card will be charged monthly\n$25/mo\n$250/mo\n$500/mo\nAllowances\nBandwidth\n250 GB\n1000 GB\n4 TB\nStorage\n250 GB\n1000 GB\n2 TB\nVideo limit\nunlimited\nunlimited\nunlimited\nSeats\n5\n20\n20+\nSupport\nEmail support\nLive chat\nTelephone support\nCustomer success manager\nSecurity\nDomain control\nAdvanced embed security\nEncrypted playback\nPassword protection\nVideo scheduling\nIntegration\nPlayer API\nDeveloper API\nMigration assistance\ncontact\n\nMarketing\n& Advertising\nVideo analytics\nVideo advertising\nMail catcher\nWhite label embed codes\nPlayer\nPlaylists\nCustomizable video player\nMulti language subtitles\nPodcasts\nOverages\nStandard playback\n$0.50/GB\n$0.50/GB\ncontact\nChina playback\n$1.00/GB\ncontact\nUpgrades\nAdditional domains\nAdditional seats\nAdditional storage\nFlexible bandwidth pack\ncontact\n\nEncoding Quality\nRenditions\nSelectable renditions\n2\n3\n4+\nDo not encode - source\nUltra low definition\nLow definition\nSD - low\nSD - high\nHD - 720p\nHD - 1080p\nUltra-HD - 2.5k\nUltra-HD - 4k\ncontact\nPRICING FAQ\nWhat do I get with my free trial?\nWhat if I go over my bandwidth?\nCan I purchase more than 5TB?\nWhat is the price for storage overages?\nCan I have features that aren't included in my plan?\nHow much bandwidth do I need?\nIs there a long term contract?": "{'width': 1200, 'height': 5579}",
#  u'FREE TRIAL': "{'width': 188, 'height': 60}",
#  u'FREE TRIAL FREE TRIAL FREE TRIAL': "{'width': 565, 'height': 60}",
#  u'FULL FEATURE LIST': "{'width': 960, 'height': 135}",
#  u'Flexible bandwidth pack': "{'width': 281, 'height': 39}",
#  u'Flexible bandwidth pack\ncontact': "{'width': 846, 'height': 39}",
#  u'HD - 1080p': "{'width': 281, 'height': 39}",
#  u'HD - 720p': "{'width': 281, 'height': 39}",
#  u'High volume playback\nFlexible bandwidth pack\nPlatform developer': "{'width': 230, 'height': 124}",
#  u'How much bandwidth do I need?': "{'width': 904, 'height': 72}",
#  u"If you exceed your allowance regularly contact us to discuss your bandwidth needs. We'll find a plan that's right for you. We offer high volume pricing for accounts over 4TB.": "{'width': 1200, 'height': 112}",
#  u'Integration': "{'width': 281, 'height': 34}",
#  u'Is there a long term contract?': "{'width': 904, 'height': 72}",
#  u'Live Streaming\nUltra HD 4K Delivery\nCustomer Success Manager': "{'width': 228, 'height': 124}",
#  u'Live chat': "{'width': 281, 'height': 39}",
#  u'Low definition': "{'width': 281, 'height': 39}",
#  u'Mail catcher': "{'width': 281, 'height': 39}",
#  u'Marketing\n& Advertising': "{'width': 281, 'height': 68}",
#  u'Migration assistance': "{'width': 281, 'height': 39}",
#  u'Migration assistance\ncontact': "{'width': 846, 'height': 39}",
#  u'Multi language subtitles': "{'width': 281, 'height': 39}",
#  u'Overages': "{'width': 281, 'height': 34}",
#  u'PAY ANNUALLY\n(GET 2 MONTHS FREE)': "{'width': 142, 'height': 60}",
#  u'PAY MONTHLY': "{'width': 142, 'height': 60}",
#  u'PAY MONTHLY\nPAY ANNUALLY\n(GET 2 MONTHS FREE)': "{'width': 284, 'height': 60}",
#  u'PAY MONTHLY\nPAY ANNUALLY\n(GET 2 MONTHS FREE)\nSELF SERVICE\n$20.83 /month\nSAVE $50\nSTART FREE TRIAL\nAll core features including...\nVideo Analytics\nCustomizable video player\nAdaptive streaming\nDomain control\nSee all features\n250 GB Bandwidth\n250 GB Storage\nEmail support\nWhat happens if I exceed my allowance?\nPREMIUM\n$208.33 /month\nSAVE $500\nSTART FREE TRIAL\nSelf Service, Plus...\nDeveloper APIs\nAdvanced Video Security\nIn China Video Playback\nVideo Advertising\nSee all features\n1000 GB Bandwidth*\n1000 GB Storage\nEmail & telephone support\nWhat happens if I exceed my allowance?\nENTERPRISE\n$416.67 /month\nSAVE $1000\nSTART FREE TRIAL\nPremium, Plus...\nLive Streaming\nUltra HD 4K Delivery\nCustomer Success Manager\nSee all features\n4 TB Bandwidth*\n2 TB Storage\nDedicated account management\nWhat happens if I exceed my allowance?\nCUSTOM\nNeed more bandwidth? Or something a little more specific?\nCONTACT US\nHigh volume playback\nFlexible bandwidth pack\nPlatform developer\nTell us how you\u2019re using video and we can design a plan that\u2019s right for you. Access Enterprise features, video migrations, developer licenses and more!\n*100GB of allowance can be used towards China playback. Overages apply thereafter. Please contact us if you require additional bandwidth for this territory.': "{'width': 1200, 'height': 887}",
#  u'PREMIUM': "{'width': 188, 'height': 34}",
#  u'PREMIUM\n$208.33 /month\nSAVE $500': "{'width': 228, 'height': 140}",
#  u'PREMIUM\n$208.33 /month\nSAVE $500\nSTART FREE TRIAL\nSelf Service, Plus...\nDeveloper APIs\nAdvanced Video Security\nIn China Video Playback\nVideo Advertising\nSee all features\n1000 GB Bandwidth*\n1000 GB Storage\nEmail & telephone support\nWhat happens if I exceed my allowance?': "{'width': 264, 'height': 669}",
#  u"PRICING FAQ\nWhat do I get with my free trial?\nWhat if I go over my bandwidth?\nCan I purchase more than 5TB?\nWhat is the price for storage overages?\nCan I have features that aren't included in my plan?\nHow much bandwidth do I need?\nIs there a long term contract?": "{'width': 1000, 'height': 739}",
#  u'PRODUCT\nFeatures\nPricing\nSolutions\nProduct Updates\nMore\nCOMPANY\nAbout\nTeam\nJobs\nCase Studies\nIntegrations\nSUPPORT & TOOLS\nHelp & Support\nDevelopers / API\nTools\nGlossary\nResources\nBlog\nKeep up with our updates\n1-844-527-2770\nTalk to us\nContact\nDrop us a line': "{'width': 1144, 'height': 356}",
#  u'PRODUCT\nFeatures\nPricing\nSolutions\nProduct Updates\nMore\nCOMPANY\nAbout\nTeam\nJobs\nCase Studies\nIntegrations\nSUPPORT & TOOLS\nHelp & Support\nDevelopers / API\nTools\nGlossary\nResources\nBlog\nKeep up with our updates\n1-844-527-2770\nTalk to us\nContact\nDrop us a line\n\xa9 2018 vzaar Limited. Registered in England.\nCompany Number: 0617 6218 VAT: GB 919 256 111\nPrivacy | Terms and conditions | \u9ed4ICP\u590715008702\u53f7': "{'width': 1200, 'height': 440}",
#  u'Password protection': "{'width': 281, 'height': 39}",
#  u'Player': "{'width': 281, 'height': 34}",
#  u'Player API': "{'width': 281, 'height': 39}",
#  u'Playlists': "{'width': 281, 'height': 39}",
#  u'Podcasts': "{'width': 281, 'height': 39}",
#  u'Premium, Plus...': "{'width': 228, 'height': 40}",
#  u'Pricing': "{'width': 281, 'height': 34}",
#  u'SAVE $1000': "{'width': 228, 'height': 24}",
#  u'SAVE $50': "{'width': 228, 'height': 24}",
#  u'SAVE $500': "{'width': 228, 'height': 24}",
#  u'SD - high': "{'width': 281, 'height': 39}",
#  u'SD - low': "{'width': 281, 'height': 39}",
#  u'SELF SERVICE': "{'width': 188, 'height': 34}",
#  u'SELF SERVICE\n$20.83 /month\nSAVE $50': "{'width': 228, 'height': 140}",
#  u'SELF SERVICE\n$20.83 /month\nSAVE $50\nSTART FREE TRIAL\nAll core features including...\nVideo Analytics\nCustomizable video player\nAdaptive streaming\nDomain control\nSee all features\n250 GB Bandwidth\n250 GB Storage\nEmail support\nWhat happens if I exceed my allowance?': "{'width': 264, 'height': 669}",
#  u'SELF SERVICE\n$20.83 /month\nSAVE $50\nSTART FREE TRIAL\nAll core features including...\nVideo Analytics\nCustomizable video player\nAdaptive streaming\nDomain control\nSee all features\n250 GB Bandwidth\n250 GB Storage\nEmail support\nWhat happens if I exceed my allowance?\nPREMIUM\n$208.33 /month\nSAVE $500\nSTART FREE TRIAL\nSelf Service, Plus...\nDeveloper APIs\nAdvanced Video Security\nIn China Video Playback\nVideo Advertising\nSee all features\n1000 GB Bandwidth*\n1000 GB Storage\nEmail & telephone support\nWhat happens if I exceed my allowance?\nENTERPRISE\n$416.67 /month\nSAVE $1000\nSTART FREE TRIAL\nPremium, Plus...\nLive Streaming\nUltra HD 4K Delivery\nCustomer Success Manager\nSee all features\n4 TB Bandwidth*\n2 TB Storage\nDedicated account management\nWhat happens if I exceed my allowance?\nCUSTOM\nNeed more bandwidth? Or something a little more specific?\nCONTACT US\nHigh volume playback\nFlexible bandwidth pack\nPlatform developer\nTell us how you\u2019re using video and we can design a plan that\u2019s right for you. Access Enterprise features, video migrations, developer licenses and more!': "{'width': 1200, 'height': 699}",
#  u'SELF SERVICE\nPREMIUM\nENTERPRISE': "{'width': 565, 'height': 34}",
#  u'SELF SERVICE\nPREMIUM\nENTERPRISE\nFREE TRIAL FREE TRIAL FREE TRIAL': "{'width': 846, 'height': 94}",
#  u'SELF SERVICE\nPREMIUM\nENTERPRISE\nFREE TRIAL FREE TRIAL FREE TRIAL\nPricing\nBilled Annually\nYour card will be charged annually\n$20.83/mo\nSave $50\n$208.33/mo\nSave $500\n$416.67/mo\nSave $1000\nBilled Monthly\nYour card will be charged monthly\n$25/mo\n$250/mo\n$500/mo\nAllowances\nBandwidth\n250 GB\n1000 GB\n4 TB\nStorage\n250 GB\n1000 GB\n2 TB\nVideo limit\nunlimited\nunlimited\nunlimited\nSeats\n5\n20\n20+\nSupport\nEmail support\nLive chat\nTelephone support\nCustomer success manager\nSecurity\nDomain control\nAdvanced embed security\nEncrypted playback\nPassword protection\nVideo scheduling\nIntegration\nPlayer API\nDeveloper API\nMigration assistance\ncontact\n\nMarketing\n& Advertising\nVideo analytics\nVideo advertising\nMail catcher\nWhite label embed codes\nPlayer\nPlaylists\nCustomizable video player\nMulti language subtitles\nPodcasts\nOverages\nStandard playback\n$0.50/GB\n$0.50/GB\ncontact\nChina playback\n$1.00/GB\ncontact\nUpgrades\nAdditional domains\nAdditional seats\nAdditional storage\nFlexible bandwidth pack\ncontact\n\nEncoding Quality\nRenditions\nSelectable renditions\n2\n3\n4+\nDo not encode - source\nUltra low definition\nLow definition\nSD - low\nSD - high\nHD - 720p\nHD - 1080p\nUltra-HD - 2.5k\nUltra-HD - 4k\ncontact': "{'width': 846, 'height': 2463}",
#  u'START FREE TRIAL': "{'width': 228, 'height': 80}",
#  u'Seats': "{'width': 281, 'height': 34}",
#  u'Seats\n5\n20\n20+': "{'width': 846, 'height': 34}",
#  u'Security': "{'width': 281, 'height': 34}",
#  u'See all features': "{'width': 228, 'height': 40}",
#  u'Selectable renditions': "{'width': 281, 'height': 34}",
#  u'Selectable renditions\n2\n3\n4+': "{'width': 846, 'height': 34}",
#  u'Self Service, Plus...': "{'width': 228, 'height': 40}",
#  u'Standard Playback\n$0.50 /GB': "{'width': 270, 'height': 152}",
#  u'Standard Playback\n$0.50 /GB\nChina Playback\n$1.00 /GB': "{'width': 1200, 'height': 202}",
#  u'Standard playback': "{'width': 281, 'height': 34}",
#  u'Standard playback\n$0.50/GB\n$0.50/GB\ncontact': "{'width': 846, 'height': 34}",
#  u'Storage': "{'width': 281, 'height': 34}",
#  u'Storage\n250 GB\n1000 GB\n2 TB': "{'width': 846, 'height': 34}",
#  u'Support': "{'width': 281, 'height': 34}",
#  u'Telephone support': "{'width': 281, 'height': 39}",
#  u'Tell us how you\u2019re using video and we can design a plan that\u2019s right for you. Access Enterprise features, video migrations, developer licenses and more!': "{'width': 230, 'height': 178}",
#  u'Ultra low definition': "{'width': 281, 'height': 39}",
#  u'Ultra-HD - 2.5k': "{'width': 281, 'height': 39}",
#  u'Ultra-HD - 4k': "{'width': 281, 'height': 39}",
#  u'Ultra-HD - 4k\ncontact': "{'width': 846, 'height': 39}",
#  u'Upgrades': "{'width': 281, 'height': 34}",
#  u'Video Analytics\nCustomizable video player\nAdaptive streaming\nDomain control': "{'width': 228, 'height': 124}",
#  u'Video advertising': "{'width': 281, 'height': 39}",
#  u'Video analytics': "{'width': 281, 'height': 39}",
#  u'Video limit': "{'width': 281, 'height': 34}",
#  u'Video limit\nunlimited\nunlimited\nunlimited': "{'width': 846, 'height': 34}",
#  u'Video scheduling': "{'width': 281, 'height': 39}",
#  u'WHAT HAPPENS IF I EXCEED MY ALLOWANCE?': "{'width': 1200, 'height': 95}",
#  u'What do I get with my free trial?': "{'width': 904, 'height': 72}",
#  u'What happens if I exceed my allowance?': "{'width': 204, 'height': 44}",
#  u'What if I go over my bandwidth?': "{'width': 904, 'height': 72}",
#  u'What is the price for storage overages?': "{'width': 904, 'height': 72}",
#  u'White label embed codes': "{'width': 281, 'height': 39}",
#  u'Your videos just keep on playing. You simply pay competitive rates for any additional bandwidth you use.': "{'width': 1200, 'height': 88}",
#  u'contact': "{'width': 188, 'height': 39}",
#  u'unlimited': "{'width': 188, 'height': 34}",
#  u'unlimited\nunlimited\nunlimited': "{'width': 565, 'height': 34}"}

# %%
e=pd.DataFrame(data=['None'])

# %%
e
# Out:
#       0
# 0  None

# %%
a="http:/insights.axtria.com/axtria-5-step-guides-sales-management-and-sales-operations-planning;http:/insights.axtria.com/designing-incentive-compensation-plans-for-specialty-products;http:/insights.axtria.com/whitepaper-pricing-and-market-effects-of-biosimilars-entry-in-the-us;https:/axtria.com/cloud-commercial-operations-solutions/multi-channel-call-planning-and-sales-targeting/;https:/axtria.com/platforms/axtria-salesiq-sales-planning-and-sales-operations-platform/"
a.split(";")
# Out:
# ['http:/insights.axtria.com/axtria-5-step-guides-sales-management-and-sales-operations-planning',
#  'http:/insights.axtria.com/designing-incentive-compensation-plans-for-specialty-products',
#  'http:/insights.axtria.com/whitepaper-pricing-and-market-effects-of-biosimilars-entry-in-the-us',
#  'https:/axtria.com/cloud-commercial-operations-solutions/multi-channel-call-planning-and-sales-targeting/',
#  'https:/axtria.com/platforms/axtria-salesiq-sales-planning-and-sales-operations-platform/']
